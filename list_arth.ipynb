# %% [markdown]
# fucker

# %%
print("behen ke loude")
# Out:
# behen ke loude

# %%
a=20
b=30
diff=a-b
print(diff)
# Out:
# -10

# %%
x=['hh','yy','oo','tt']
print(x)
print(type(x))
x.append('ww')
print(x)
# Out:
# ['hh', 'yy', 'oo', 'tt']
# <class 'list'>
# ['hh', 'yy', 'oo', 'tt', 'ww']

# %%
lis1=['aa','ss','dd','uu']
print(lis1)
lis2=['ry','we','pp']
lis1.append('tt')
print(lis1)
print(lis2)
# Out:
# ['aa', 'ss', 'dd', 'uu']
# []

# %%
lis1=['aa','ss','dd','uu']
print(lis1)
lis2=['ry','we','pp']
lis1.append('tt')
print(lis1)
print(lis2)
# Out:
# ['aa', 'ss', 'dd', 'uu']
# ['aa', 'ss', 'dd', 'uu', 'tt']
# ['ry', 'we', 'pp']

# %%
lis1=['aa','ss','dd','uu']
print(lis1)
lis2=['ry','we','pp']
lis1.append('tt')
print(lis1)
print(lis2)
lis=lis1+lis2
print(lis)
# Out:
# ['aa', 'ss', 'dd', 'uu']
# ['aa', 'ss', 'dd', 'uu', 'tt']
# ['ry', 'we', 'pp']
# ['aa', 'ss', 'dd', 'uu', 'tt', 'ry', 'we', 'pp']

# %%
x=4
y=7.9
print(type(x))
print(type(y))
z=x+y
print(z)
# Out:
# <class 'int'>
# <class 'float'>
# 11.9

# %%
 a=int(input("enter a : "))
 b=int(input("enter b : "))
sum=a+b
print(sum)
# Out:
# enter a : 3
# enter b : 2
# 5

# %%
b1="green"
b2="yellow"
b3="red"
b4="blue"

pb=input("pick a ball colour : ")

if pb==b1:
 print("the picked colour is Green")

elif pb == b2:
 print("the picked colour is yellow")

elif pb==b3:
 print("the picked colour is red")

else:
 print("the picked colour is blue")
# Out:
# pick a ball colour : yellow
# the picked colour is yellow

# %%
a=4
b=2
sum=a+b
diff=a-b
product=a*b
div=a/b
mod=a%b
power=a**b

print(sum)
print(diff)
print(product)
print(div)
print(mod)
print(power)
# Out:
# 6
# 2
# 8
# 2.0
# 0
# 16

# %%
age=int(input("enetr the age : "))
print(age>=18 and age<=30)
print(age>=18 or age<=30)
# Out:
# enetr the age : 1
# False
# True

# %%
print(8 & 12)
print(0xf & 0xe)

print(8 | 12)
print(0xf | 0xe)

print(8 ^ 12)
print(0xf ^ 0xe)
# Out:
# 8
# 14
# 12
# 15
# 4
# 1

# %%
a=8
a+=3
print(a)

a=8
a-=3
print(a)

a=8
a*=3
print(a)


a=8
a/=3
print(a)
# Out:
# 11
# 5
# 24
# 2.6666666666666665
